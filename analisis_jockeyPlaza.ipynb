# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from glob import glob
# Aplicar configuraciones de visualización total de Pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)

# %%
import func_gcp as func_gcp

# %%
query_ventas = '''
    select *
    from spsa-operaciones-seg-sd.dst_gestion_operativa.cv_venta
    where codigo_local IN ('V019', 'V094', 'V116')
    and year>= 2025
'''

# %%
dff_ventas = func_gcp.read_query(query_ventas)
# Out:
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\auth\_default.py:113: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# d:\Usuarios\SP44812227\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\cloud\bigquery\table.py:2086: UserWarning: BigQuery Storage module not found, fetch data with the REST endpoint instead.
#   warnings.warn(

# %%
dff_ventas.head()
# Out:
#    mes  year nombre_division          nombre_seccion  \
# 0   10  2025       ABARROTES  COMESTIBLES ESPECIALES
# 1   10  2025       ABARROTES        CUIDADO PERSONAL
# 2    7  2025       ABARROTES                 LACTEOS
# 3    3  2025       ABARROTES        CUIDADO PERSONAL
# 4    3  2025       ABARROTES        CUIDADO PERSONAL
#
#                    nombre_area        nombre_linea          nombre_familia  \
# 0                  COMESTIBLES           DESAYUNOS  CEREALES PARA PREPARAR
# 1  CUIDADO PERSONAL Y LIMPIEZA  CUIDADO DE LA PIEL          CUIDADO FACIAL
# 2         LACTEOS Y CONGELADOS              HUEVOS                  HUEVOS
# 3  CUIDADO PERSONAL Y LIMPIEZA          PERFUMERIA      ACCESORIOS DE BAÑO
# 4  CUIDADO PERSONAL Y LIMPIEZA          PERFUMERIA           ANTIBACTERIAL
#
#   nombre_tipo_marca       tipo_venta sub_tipo_Venta codigo_local tipo_sss  \
# 0           PROPIOS        Last Mile     Agora Shop         V094      SSS
# ...

# %%
dff_ventas["sub_tipo_Venta"].unique()
# Out:
# array(['Agora Shop', 'Ecommerce', 'Venta POS', 'Venta CNegocio'],
#       dtype=object)

# %%
dff_ventas["tipo_venta"].unique()

dff_ventas.groupby(["tipo_venta", "sub_tipo_Venta"]).size()
# Out:
# tipo_venta       sub_tipo_Venta
# Last Mile        Agora Shop           92
# Venta CNegocio   Venta CNegocio        1
# Venta Ecommerce  Ecommerce          1453
# Venta POS        Venta POS         24488
# dtype: int64

# %%
dff_ventas["nombre_linea"].unique()
# Out:
# array(['DESAYUNOS', 'CUIDADO DE LA PIEL', 'HUEVOS', 'PERFUMERIA',
#        'CONSERVAS', 'PESCADOS', 'DESINFECTANTES', 'YOGURT', 'VINO',
#        'FARMACIA', 'CUIDADO BUCAL', 'CERVEZA', 'CONFITERIA', 'FRUTAS',
#        'AGUAS', 'POLLO', 'SIN HUESO', 'MENESTRAS', 'ARROZ',
#        'CONDIMENTOS/ADEREZOS', 'PESADOS', 'LIVIANOS',
#        'CUIDADO DE LA ROPA', 'LIMPIEZA', 'REPOSTERIA',
#        'PANADERIA INDUSTRIAL', 'PAPELERIA LIMPIEZA', 'FONDOS',
#        'CUIDADO FAMILIAR', 'BEBIDAS FUNCIONALES', 'LICORES', 'PIQUEOS',
#        'ESPUMANTE', 'CUIDADO DEL CABELLO', 'LECHE ENVASADA', 'VARIOS',
#        'ACEITES', 'MAQUILLAJE', 'MASCOTAS', 'MENAJE', 'FIDEOS',
#        'TEXTIL HOGAR', 'LIMPIADORES / CUIDADO DEL HOGAR', 'LIBRERIA',
#        'AUTOMOTOR', 'FERRETERIA', 'BEBIDAS', 'BLANDOS', 'PASTELERIA SECA',
#        'ESPECIAL', 'BUFFET', 'ESTACIONALES - AIRE  LIBRE Y DEPORT',
#        'ALIMENTOS', 'POSTRES', 'SANGUCHES', 'CHORIZO', 'CIGARROS/HABANOS',
# ...

# %%
dff_ventas["nombre_seccion"].unique()
# Out:
# array(['COMESTIBLES ESPECIALES', 'CUIDADO PERSONAL', 'LACTEOS',
#        'PESCADOS', 'LIMPIEZA', 'BEBIDAS CON ALCOHOL', 'FRUTAS',
#        'BEBIDAS SIN ALCOHOL', 'AVES', 'VACUNO', 'COMESTIBLES BASICOS',
#        'VERDURAS', 'BAZAR', 'PARA LLEVAR', 'VARIOS', 'HOGAR',
#        'RESTAURANTS', 'QUESOS', 'PASTELERIA', 'PANADERIA', 'CONGELADOS',
#        'CHORIZO', 'TABACO', 'FIAMBRES', 'CERDO', 'MARISCOS', 'TELEFONIA',
#        'BEBES', 'INSUMOS', 'BOLSAS COMPOSTABLES', 'OTRAS ESPECIES',
#        'CALZADO Y ACCESORIOS', 'NIÑOS', 'DAMAS', 'PEQUEÑOS ELECTRODOM',
#        'TARJETA', 'VIDEO', 'CABALLEROS', 'LINEA BLANCA', 'COMPUTO',
#        'AUDIO'], dtype=object)

# %%
dff_ventas
# Out:
#        mes  year nombre_division          nombre_seccion  \
# 0       10  2025       ABARROTES  COMESTIBLES ESPECIALES
# 1       10  2025       ABARROTES        CUIDADO PERSONAL
# 2        7  2025       ABARROTES                 LACTEOS
# 3        3  2025       ABARROTES        CUIDADO PERSONAL
# 4        3  2025       ABARROTES        CUIDADO PERSONAL
# ...    ...   ...             ...                     ...
# 26029    5  2025       ABARROTES     COMESTIBLES BASICOS
# 26030    6  2025       ABARROTES  COMESTIBLES ESPECIALES
# 26031    4  2025       ABARROTES  COMESTIBLES ESPECIALES
# 26032    1  2025       ABARROTES  COMESTIBLES ESPECIALES
# 26033    1  2025       ABARROTES  COMESTIBLES ESPECIALES
#
#                        nombre_area          nombre_linea  \
# 0                      COMESTIBLES             DESAYUNOS
# 1      CUIDADO PERSONAL Y LIMPIEZA    CUIDADO DE LA PIEL
# 2             LACTEOS Y CONGELADOS                HUEVOS
# ...

# %%
dff_ventas[dff_ventas["nombre_division"]=="NON FOOD"]

dff_ventas[(dff_ventas["codigo_local"]=="V094")&(dff_ventas["year"]==2025)&(dff_ventas["nombre_division"]=="MISCELANEOS")].groupby(["nombre_division", "nombre_area", "nombre_linea", "nombre_familia"])["venta"].sum()
# Out:
# nombre_division  nombre_area  nombre_linea         nombre_familia
# MISCELANEOS      MISCELANEOS  BOLSAS COMPOSTABLES  MASS                   0.00
#                                                    PLAZA VEA              0.00
#                                                    VIVANDA            88709.45
#                               VARIOS               VARIOS            264528.27
# Name: venta, dtype: float64

# %%
dff_ventas[(dff_ventas["codigo_local"]=="V094")&(dff_ventas["year"]==2025)]["venta"].sum()
# Out:
# np.float64(38359405.04000001)
